# %%
import distances as ds

# %%
import thisModule as tm

# %%
import descriptorsV2 as desv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
tm.plotResults(ds.distance_texture(tm.ImageAsArrayNum(16),tm.getImages(66)))
