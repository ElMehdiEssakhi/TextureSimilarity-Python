# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import thisModule as tm

# %%
import descriptorsV2 as dv2

# %%
img1=tm.ImageAsArray('mandi.tif','preprocessDB')

# %%
gray1=tm.rgb2gray(img1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 gray1=tm.rgb2gray(img1)
#
# File c:\WorkDir\Python\ml\similarity search\thisModule.py:16, in rgb2gray(I)
#      14 def rgb2gray(I): #not suted for png images
#      15     array=np.array(I)
# ---> 16     gray=0.2989*array[0:,0:,0]+0.5870*array[0:,0:,1]+0.1140*array[0:,0:,2]
#      17     return gray.astype(np.uint8)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
print(gray1[0,:10])
# Out:
# [167 167 167 167 167 168 168 168 170 170]

# %%
glcm1=dv2.cooccurence(img1)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img1, cmap='gray')
plt.subplot(1,2,2)
plt.imshow(glcm1, cmap='gray', norm='log')
